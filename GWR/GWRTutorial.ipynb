# %% [markdown]
# # GWR Tutorial

# %% [markdown]
# We will use the Bristol Airbnb dataset from last week's spatial regression lecture to do the GWR and mGWR analysis.
#
# Tutorial target:
# 1. Fit a OLS model
# 2. Fit a GWR model
# 3. Fit a mGWR model
# 4. Map out the significant parameters based on the adjusted t-value of GWR and mGWR model, and then explain your findings

# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import libpysal as ps 
from libpysal.weights import Queen
from esda.moran import Moran
import statsmodels.api as sm

# MGWR functions
from mgwr.gwr import GWR,MGWR
from mgwr.sel_bw import Sel_BW

# %%
df = pd.read_csv(r'Data/listings.csv.gz')
